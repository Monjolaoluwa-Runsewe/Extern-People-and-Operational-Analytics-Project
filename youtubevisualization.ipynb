# %% [markdown]
# <a href="https://colab.research.google.com/github/Monjolaoluwa-Runsewe/Extern-People-and-Operational-Analytics-Project/blob/main/youtubevisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/youtube.xlsx')

# %%
from collections import Counter

# Join all cleaned reviews into one big string, then split into words
all_words = ' '.join(df['cleaned_Transcript']).split()

# Count frequency of each word
word_counts = Counter(all_words)

# %%
print(word_counts.most_common(5))
# Out:
# [('work', 40), ('get', 20), ('long', 13), ('hours', 12), ('job', 12)]

# %%
most_common_words = word_counts.most_common(10)
words, counts = zip(*most_common_words)
plt.bar(words, counts)
plt.title("Top 10 keywords(Unigrams)")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
stop_keywords=['team', 'compamy', 'job','work']
filtered_words= [word for word in all_words if word not in stop_keywords]
filtered_counts = Counter(filtered_words)

# %%
from nltk import bigrams
from nltk.util import ngrams
bigrams = list(ngrams(all_words,2))
trigrams = list(ngrams(all_words,3))
bigrams_counts = Counter(bigrams)
trigrams= Counter(trigrams)
print(bigrams_counts.most_common)
# Out:
# <bound method Counter.most_common of Counter({('physically', 'demanding'): 5, ('break', 'time'): 4, ('work', 'life'): 3, ('long', 'hours'): 3, ('physical', 'mental'): 3, ('work', 'environment'): 3, ('12', 'hours'): 3, ('long', 'shifts'): 3, ('use', 'break'): 3, ('fast', 'paced'): 2, ('working', 'environment'): 2, ('10', 'hours'): 2, ('hard', 'find'): 2, ('long', 'term'): 2, ('bathroom', 'breaks'): 2, ('mandatory', 'overtime'): 2, ('fines', 'de'): 2, ('de', 'semana'): 2, ('work', 'work'): 2, ('lot', 'work'): 2, ('work', 'like'): 2, ('mandatory', 'extra'): 2, ('extra', 'time'): 2, ('life', 'balance'): 2, ('moved', 'around'): 2, ('around', 'lot'): 2, ('different', 'departments'): 2, ('new', 'skills'): 2, ('ground', 'level'): 2, ('repetitive', 'tasks'): 2, ('heavy', 'lifting'): 2, ('sometimes', 'stressful'): 2, ('focus', 'focus'): 2, ('10', 'hour'): 2, ('hour', 'shifts'): 2, ('mentally', 'draining'): 2, ('internal', 'politics'): 2, ('heavy', 'work'): 2, ('high', 'expectations'): 2, ('time', 'get'): 2, ('you’ll', 'get'): 2, ('high', 'turnover'): 2, ('get', 'trouble'): 2, ('prime', 'day'): 2, ('inhumane', 'draining'): 1, ('draining', 'physically'): 1, ('physically', 'amp'): 1, ('amp', 'mentally'): 1, ('mentally', 'sticks'): 1, ('sticks', 'rules'): 1, ('rules', 'completing'): 1, ('completing', 'targets'): 1, ('targets', 'otherwise'): 1, ('otherwise', 'get'): 1, ('get', 'warning'): 1, ('warning', 'limited'): 1, ('limited', 'opportunities'): 1, ('opportunities', 'advancementno'): 1, ('advancementno', 'clear'): 1, ('clear', 'path'): 1, ('path', 'promotion'): 1, ('promotion', 'tough'): 1, ('tough', 'body'): 1, ('body', 'labor'): 1, ('labor', 'intensive'): 1, ('intensive', 'hiring'): 1, ('hiring', 'permanent'): 1, ('permanent', 'employees'): 1, ('employees', 'directly'): 1, ('directly', 'management'): 1, ('management', 'care'): 1, ('care', 'employees'): 1, ('employees', 'hours'): 1, ('hours', 'way'): 1, ('way', 'long'): 1, ('long', 'fast'): 1, ('paced', 'working'): 1, ('environment', 'weight'): 1, ('weight', 'lifting'): 1, ('lifting', 'people'): 1, ('people', 'charge'): 1, ('charge', 'wasnt'): 1, ('wasnt', 'good'): 1, ('good', 'management'): 1, ('management', 'absolutely'): 1, ('absolutely', 'terrible'): 1, ('terrible', 'communicating'): 1, ('communicating', 'work'): 1, ('life', 'less'): 1, ('less', 'sleep'): 1, ('sleep', 'standing'): 1, ('standing', '10'): 1, ('hours', 'noise'): 1, ('noise', 'safety'): 1, ('safety', 'hazards'): 1, ('hazards', 'overworking'): 1, ('overworking', 'get'): 1, ('get', 'write'): 1, ('write', 'ups'): 1, ('ups', 'meeting'): 1, ('meeting', 'rate'): 1, ('rate', 'expectations'): 1, ('expectations', 'workplace'): 1, ('workplace', 'culture'): 1, ('culture', 'bad'): 1, ('bad', 'nightshift'): 1, ('nightshift', 'overtime'): 1, ('overtime', 'cons'): 1, ('cons', 'physical'): 1, ('physical', 'job'): 1, ('job', 'prepare'): 1, ('prepare', 'tired'): 1, ('tired', 'cons'): 1, ('cons', 'knowledge'): 1, ('knowledge', 'fired'): 1, ('fired', 'without'): 1, ('without', 'notification'): 1, ('notification', 'one'): 1, ('one', 'day'): 1, ('day', 'badge'): 1, ('badge', 'didnt'): 1, ('didnt', 'work'): 1, ('work', 'wasting'): 1, ('wasting', 'time'): 1, ('time', 'bus'): 1, ('bus', 'fare'): 1, ('fare', 'contract'): 1, ('contract', 'extenscion'): 1, ('extenscion', 'hard'): 1, ('find', 'anything'): 1, ('anything', 'amazon'): 1, ('amazon', 'long'): 1, ('term', 'job'): 1, ('job', 'work'): 1, ('work', 'feel'): 1, ('feel', 'repetitive'): 1, ('repetitive', 'boring'): 1, ('boring', 'favoritism'): 1, ('favoritism', 'like'): 1, ('like', 'job'): 1, ('job', 'peak'): 1, ('peak', 'season'): 1, ('season', 'leave'): 1, ('leave', 'struggling'): 1, ('struggling', 'bit'): 1, ('bit', 'stressful'): 1, ('stressful', 'honest'): 1, ('honest', 'tight'): 1, ('tight', 'workload'): 1, ('workload', 'station'): 1, ('station', 'dieser'): 1, ('dieser', 'fc'): 1, ('fc', 'werden'): 1, ('werden', 'mitarbeiter'): 1, ('mitarbeiter', 'und'): 1, ('und', 'neueinstellungen'): 1, (' ...

# %%
common_bigrams = bigrams_counts.most_common(5)
bigram_labels = [' '.join(bg) for bg, count in common_bigrams]
bigram_counts = [count for bg, count in common_bigrams]
plt.bar(bigram_labels, bigram_counts)
plt.title("Top 5 Bigrams")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(all_words))
plt.figure(figsize=(15,7))
plt.imshow(wordcloud, interpolation ='bilinear')
plt.axis('off')
plt.title("Keyword Word Cloud")
plt.show()
