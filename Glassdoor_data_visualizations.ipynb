# %% [markdown]
# <a href="https://colab.research.google.com/github/Monjolaoluwa-Runsewe/Extern-People-and-Operational-Analytics-Project/blob/main/Glassdoor_data_visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_excel('/content/glassdoor.xlsx')

# %%
from collections import Counter
all_words= ' '.join(df['cleaned_review_cons'].astype(str)).split()
word_counts= Counter(all_words)
print(word_counts.most_common(5))
# Out:
# [('and', 119), ('to', 91), ('work', 62), ('you', 54), ('the', 54)]

# %%
most_common_words = word_counts.most_common(10)
words, counts = zip(*most_common_words)
plt.bar(words, counts)
plt.title("Top 10 keywords(Unigrams)")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
stop_keywords=['team', 'compamy', 'job','work']
filtered_words= [word for word in all_words if word not in stop_keywords]
filtered_counts = Counter(filtered_words)

# %%
most_common_words=filtered_counts.most_common(10)
word, counts = zip(*most_common_words)
plt.bar(word, counts)
plt.title("Top 10 Keywords(Unigrams)")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from nltk import bigrams
from nltk.util import ngrams
bigrams = list(ngrams(all_words,2))
trigrams = list(ngrams(all_words,3))
bigrams_counts = Counter(bigrams)
trigrams= Counter(trigrams)
print(bigrams_counts.most_common)
# Out:
# <bound method Counter.most_common of Counter({('pay', 'and'): 8, ('if', 'you'): 8, ('to', 'work'): 8, ('good', 'pay'): 7, ('Good', 'pay'): 7, ('and', 'benefits'): 7, ('lot', 'of'): 7, ('a', 'lot'): 6, ('to', 'get'): 6, ('care', 'about'): 5, ('time', 'off'): 5, ('you', 'get'): 5, ('and', 'the'): 5, ('is', 'not'): 5, ('of', 'work'): 4, ('on', 'the'): 4, ('to', 'learn'): 4, ('you', 'are'): 4, ('pay', 'for'): 4, ('work', 'and'): 4, ('and', 'not'): 4, ('Too', 'much'): 4, ('work', 'with'): 4, ('you', 'want'): 4, ('work', 'you'): 4, ('have', 'to'): 4, ('The', 'pay'): 4, ('is', 'a'): 4, ('lack', 'of'): 4, ('work', 'is'): 4, ('lots', 'of'): 4, ('can', 'be'): 4, ('the', 'same'): 4, ('on', 'your'): 4, ('for', 'the'): 4, ('your', 'break'): 4, ('you', 'have'): 3, ('easy', 'work'): 3, ('The', 'benefits'): 3, ('at', 'all'): 3, ('of', 'the'): 3, ('to', 'start'): 3, ('place', 'to'): 3, ('and', 'great'): 3, ('have', 'a'): 3, ('benefits', 'and'): 3, ('hour', 'shifts'): 3, ('work', 'environment'): 3, ('
# ...

# %%
common_bigrams = bigrams_counts.most_common(5)
bigram_labels = [' '.join(bg) for bg, count in common_bigrams]
bigram_counts = [count for bg, count in common_bigrams]
plt.bar(bigram_labels, bigram_counts)
plt.title("Top 5 Bigrams")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(all_words))
plt.figure(figsize=(15,7))
plt.imshow(wordcloud, interpolation ='bilinear')
plt.axis('off')
plt.title("Keyword Word Cloud")
plt.show()
