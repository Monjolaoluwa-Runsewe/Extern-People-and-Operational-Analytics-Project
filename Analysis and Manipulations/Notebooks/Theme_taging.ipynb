# %% [markdown]
# <a href="https://colab.research.google.com/github/Monjolaoluwa-Runsewe/Extern-People-and-Operational-Analytics-Project/blob/main/Theme_taging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('combined_sentiment_data.csv')
theme_keywords = {
    'Burnout': ['tired', 'exhausted', 'overworked', 'no break', 'stress'],
    'Training Gaps': ['training', 'onboarding', 'no support', 'confused', 'learn'],
    'Scheduling Issues': ['shift', 'hours', 'schedule', 'night shift', 'weekend']
}

# %%
def tag_themes(text, theme_keywords):
    matched_themes = []
    for theme, keywords in theme_keywords.items():
        if any(keyword in str(text).lower() for keyword in keywords):
            matched_themes.append(theme)
    return ', '.join(matched_themes) if matched_themes else ''

# %%
df['Theme'] = df['cleaned_Text'].apply(lambda x: tag_themes(x, theme_keywords))

# %%
df.to_csv('combined_with_themes.csv', index=False)
